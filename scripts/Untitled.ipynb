# %%
import numpy as np

# %%
los1 = np.load('loss_vae_32_0.005.npy')
los2 = np.load('loss_vae_64_0.02.npy')

# %%
los1.shape, los2.shape
# Out:
# ((22452, 4), (19252, 4))

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.arange(0, len(los1)), 20*los1[:, 1], color='blue', label='recons')
plt.plot(np.arange(0, len(los1)), los1[:, 3], color='orange', label='KL')
plt.legend()
plt.title("z=32, β=0.005")
plt.savefig('vae320.005.png')

# %%
plt.plot(np.arange(0, len(los2)), 20*los2[:, 1], color='blue', label='recons')
plt.plot(np.arange(0, len(los2)), los2[:, 3], color='orange', label='KL')
plt.legend()
plt.title("z=64, β=0.02")
plt.savefig('640.02.png')
